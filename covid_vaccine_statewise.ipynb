# %%
import pandas as pd

# %%
covid_vaccine_statewise_df=pd.read_csv("covid_vaccine_statewise.csv")

# %%
covid_vaccine_statewise_df
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
covid_vaccine_statewise_df.describe()  #Getting various summary statistics
# Out:
#        Total Doses Administered      Sessions        Sites   \
# count              7.621000e+03  7.621000e+03   7621.000000
# mean               9.188171e+06  4.792358e+05   2282.872064
# std                3.746180e+07  1.911511e+06   7275.973730
# min                7.000000e+00  0.000000e+00      0.000000
# 25%                1.356570e+05  6.004000e+03     69.000000
# 50%                8.182020e+05  4.547000e+04    597.000000
# 75%                6.625243e+06  3.428690e+05   1708.000000
# max                5.132284e+08  3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             7.621000e+03              7.621000e+03
# mean              7.414415e+06              1.773755e+06
# std               2.995209e+07              7.570382e+06
# min               7.000000e+00              0.000000e+00
# 25%               1.166320e+05              1.283100e+04
# 50%               6.614590e+05              1.388180e+05
# ...

# %%
import seaborn as sns

# %%
ax = sns.countplot(covid_vaccine_statewise_df['Male(Individuals Vaccinated)'])   #countplot
print(type(ax))
# Out:
# C:\Users\arghy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
import matplotlib.pyplot as plt
ax = sns.countplot(['Female(Individuals Vaccinated)'])
g = ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# C:\Users\arghy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
covid_vaccine_statewise_df[covid_vaccine_statewise_df['State']!='NA']
covid_vaccine_statewise_df[covid_vaccine_statewise_df['State']!='NA']["State"]
# Out:
# 0             India
# 1             India
# 2             India
# 3             India
# 4             India
#            ...
# 7840    West Bengal
# 7841    West Bengal
# 7842    West Bengal
# 7843    West Bengal
# 7844    West Bengal
# Name: State, Length: 7845, dtype: object

# %%
ax = sns.countplot(covid_vaccine_statewise_df[covid_vaccine_statewise_df['State']!='NA']['State'])
g= ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# C:\Users\arghy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.displot(data=covid_vaccine_statewise_df['Transgender (Doses Administered)'], kde=True)

# %%
list(set(covid_vaccine_statewise_df.dtypes.tolist()))
# Out:
# [dtype('float64'), dtype('O')]

# %%
df_num = covid_vaccine_statewise_df.select_dtypes(include = ['float64', 'int64'])
df_num
# Out:
#       Total Doses Administered  Sessions   Sites   First Dose Administered  \
# 0                      48276.0    3455.0   2957.0                  48276.0
# 1                      58604.0    8532.0   4954.0                  58604.0
# 2                      99449.0   13611.0   6583.0                  99449.0
# 3                     195525.0   17855.0   7951.0                 195525.0
# 4                     251280.0   25472.0  10504.0                 251280.0
# ...                        ...       ...      ...                      ...
# 7840                       NaN       NaN      NaN                      NaN
# 7841                       NaN       NaN      NaN                      NaN
# 7842                       NaN       NaN      NaN                      NaN
# 7843                       NaN       NaN      NaN                      NaN
# 7844                       NaN       NaN      NaN                      NaN
#
#       Second Dose Administered  Male (Doses Administered)  \
# ...

# %%
plt.subplots(figsize = (50,10))
plt.title('First Doses Administered State')
sns.boxplot(x = 'State', y = 'First Dose Administered',data = covid_vaccine_statewise_df)
# Out:
# <AxesSubplot:title={'center':'First Doses Administered State'}, xlabel='State', ylabel='First Dose Administered'>

# %%
plt.subplots(figsize = (50,10))
plt.title('Second Doses Administered State')
sns.boxplot(x = 'State', y = 'Second Dose Administered',data = covid_vaccine_statewise_df)
# Out:
# <AxesSubplot:title={'center':'Second Doses Administered State'}, xlabel='State', ylabel='Second Dose Administered'>

# %%
plt.subplots(figsize = (50,10))
plt.title('Male (Doses Administered)')
sns.boxplot(x = "State", y = "Male (Doses Administered)",data = covid_vaccine_statewise_df)
# Out:
# <AxesSubplot:title={'center':'Male (Doses Administered)'}, xlabel='State', ylabel='Male (Doses Administered)'>

# %%
plt.subplots(figsize = (50,10))
plt.title('Female (Doses Administered)')
sns.boxplot(x = "State", y = "Female (Doses Administered)",data = covid_vaccine_statewise_df)
# Out:
# <AxesSubplot:title={'center':'Female (Doses Administered)'}, xlabel='State', ylabel='Female (Doses Administered)'>

# %%
type_grouped = covid_vaccine_statewise_df[covid_vaccine_statewise_df['First Dose Administered']!='NA'].groupby(['First Dose Administered', 'Second Dose Administered']).size()
print(type_grouped)
# Out:
# First Dose Administered  Second Dose Administered
# 7.0                      0.0                         3
# 9.0                      0.0                         2
# 15.0                     0.0                         1
# 16.0                     0.0                         1
# 17.0                     0.0                         1
#                                                     ..
# 382658786.0              108102152.0                 1
# 390344882.0              109742188.0                 1
# 394599261.0              111187777.0                 1
# 395961470.0              111766433.0                 1
# 400150406.0              113077994.0                 1
# Length: 7388, dtype: int64

# %%
sns.heatmap(type_grouped.unstack(),annot=True)
plt.xticks(rotation=90)
plt.show()

# %%
sns.heatmap(df_num.corr(),annot=True, fmt='.2f', cmap= 'coolwarm')
# Out:
# <AxesSubplot:>
